# %%
targetNode
# Out:
# 7

# %%
function getLinearModel()
	
	m = Model(solver=GurobiSolver());

	# Binary Variables
	@defVar(m, deltas[1:N], Bin)

	# continous variables
	@defVar(m, 0 <= gammas[1:N] <= 1)

	# voltage and current magnitude squares
	@defVar(m, nus[1:N] >= 0)
	#@defVar(m, lij[1:N] >= 0)

	# real and reactive and complex loads and DGs
	@defVar(m, pc[1:N] >= 0)
	@defVar(m, qc[1:N] >= 0)
	@defVar(m, pg[1:N] >= 0)
	@defVar(m, qg[1:N] )


	# real and reactive power flows
	@defVar(m, P[1:N] )
	@defVar(m, Q[1:N] )

	#auxiliary variable
	@defVar(m, t)

	deltasSum = 0;

	for i=1:N
		deltasSum += deltas[i];
		
		# load constraints
		addConstraint(m, pc[i] == gammas[i]*PCD);
		addConstraint(m, qc[i] == gammas[i]*QCD);

		# PV constraints
		addConstraint(m, pg[i] == deltas[i]*PGSP);
		addConstraint(m, qg[i] == -SG + (SG + QGSP) * deltas[i]);

		# power conservation
		PSUM = pc[i] - pg[i];
		QSUM = qc[i] - qg[i];
		
		if !(i in terminalNodes)
			PSUM += P[i+1];
			QSUM += Q[i+1];		
		end

		if (i == firstLevelForkingNode)
			PSUM += P[4n+1];
			QSUM += Q[4n+1];
		elseif (i in secondLevelForkingNodes)
			PSUM += P[i+n+1];
			QSUM += Q[i+n+1];
		end

		addConstraint(m, P[i] == PSUM);
		addConstraint(m, Q[i] == QSUM);

		#ohms law
		eqSum = -2*(r*P[i] + x*Q[i]);

		if i == 1
			eqSum += nus0;
		elseif i == 4n+1
			eqSum += nus[n];
		elseif (i == 3n+1 || i == 6n+1)
			eqSum += nus[i-n-1];
		else 
			eqSum += nus[i-1];
		end

		addConstraint(m, nus[i] == eqSum);

	end

	# addConstraint(m, deltasSum == N-M);

	# define objective
	obj = 0;
	for i=1:N
		#obj += C*(1-gammas[i])
	end
	obj += W*t

	[m deltas gammas t obj nus P Q pc qc pg qg]
end

function getNonLinearModel()
	
	m = Model(solver=GurobiSolver());

	# Binary Variables
	@defVar(m, deltas[1:N], Bin)

	# continous variables
	@defVar(m, 0 <= gammas[1:N] <= 1)

	# voltage and current magnitude squares
	@defVar(m, nus[1:N] >= 0)
	@defVar(m, lij[1:N] >= 0)

	# real and reactive and complex loads and DGs
	@defVar(m, pc[1:N] >= 0)
	@defVar(m, qc[1:N] >= 0)
	@defVar(m, pg[1:N] >= 0)
	@defVar(m, qg[1:N] )


	# real and reactive power flows
	@defVar(m, P[1:N] )
	@defVar(m, Q[1:N] )

	#auxiliary variable
	@defVar(m, t)

	deltasSum = 0;

	for i=1:N
		deltasSum += deltas[i];
		
		# load constraints
		addConstraint(m, pc[i] == gammas[i]*PCD);
		addConstraint(m, qc[i] == gammas[i]*QCD);

		# PV constraints
		addConstraint(m, pg[i] == deltas[i]*PGSP);
		addConstraint(m, qg[i] == -SG + (SG + QGSP) * deltas[i]);

		# power conservation
		PSUM = pc[i] - pg[i] + r*lij[i];
		QSUM = qc[i] - qg[i] + x*lij[i];
		
		if !(i in terminalNodes)
			PSUM += P[i+1];
			QSUM += Q[i+1];		
		end

		if (i == firstLevelForkingNode)
			PSUM += P[4n+1];
			QSUM += Q[4n+1];
		elseif (i in secondLevelForkingNodes)
			PSUM += P[i+n+1];
			QSUM += Q[i+n+1];
		end

		addConstraint(m, P[i] == PSUM);
		addConstraint(m, Q[i] == QSUM);

		#ohms law
		eqSum = -2*(r*P[i] + x*Q[i]) + (r^2+x^2)*lij[i];

		if i == 1
			eqSum += nus0;
		elseif i == 4n+1
			eqSum += nus[n];
		elseif (i == 3n+1 || i == 6n+1)
			eqSum += nus[i-n-1];
		else 
			eqSum += nus[i-1];
		end

		addConstraint(m, nus[i] == eqSum);

		addConstraint(m, lij[i]*nus[i] >= P[i]^2 + Q[i]^2);

	end

	# addConstraint(m, deltasSum == N-M);

	# define objective
	obj = 0;
	for i=1:N
		obj += C*(1-gammas[i]) + r*lij[i]
	end
	obj += W*t

	[m deltas gammas t obj nus P Q pc qc pg qg]
end
# Out:
# getNonLinearModel (generic function with 1 method)

# %%
# initialize ngammas
targetNodes = zeros(Int64, M);
ngammas = ones(Float64, N);
currentBestObjValue = -W;
finalObjValue = -W;
ndeltas = zeros(Int64,N);
maxIterations = 1;

for iter = 1:maxIterations
	
	################################################################
	# Master problem 
	################################################################
	optimalAttackValues = zeros(Float64, N);
	optimalDeltasForPivotNode = Array{Int64,1}[];
	for pivotNode = 1:N
		objValues = zeros(Float64, N);
		for targetNode = 1:N
			mm = getLinearModel();
			m = mm[1]; 
			deltas = mm[2];
			gammas = mm[3];
			t = mm[4];
			obj = mm[5];
			nus = mm[6];
			P = mm[7];
			Q = mm[8];
			pc = mm[9];
			qc = mm[10];
			pg = mm[11];
			qg = mm[12];
			
			# if master problem, then minimize the cost for defender
			@setObjective(m, :Max, obj)		
						
			#voltage constraints
			addConstraint(m, t == nusL - nus[pivotNode]);					
			for i = 1:N
				addConstraint(m, gammas[i] == ngammas[i]);				
				if i == targetNode			
					addConstraint(m, deltas[i] == 0);
				else
					addConstraint(m, deltas[i] == 1);
				end
			end

			solve(m)

			objValues[targetNode] = getObjectiveValue(m);

		end

		# find optimal target nodes for the pivot node
		optimalDeltas = Int64[];
		optimalAttackValue = 0;
		for i = 1:M				
			objValue = -W;
			maxJ = -1;
			for j = 1:N
				if !(j in optimalDeltas) && objValues[j] > objValue
					objValue = objValues[j];
					maxJ = j;
				end	
			end

			optimalAttackValue += objValues[maxJ];
			push!(optimalDeltas, maxJ);
		end	

		optimalAttackValues[pivotNode] = optimalAttackValue;
		push!(optimalDeltasForPivotNode, optimalDeltas);
	end	

	# find the best pivot node to target
	maxValue = -W;
	maxI = -1;
	for i = 1:N
		if optimalAttackValues[i] > maxValue
			maxI = i;
		end
	end

	optimalTargetNodes = optimalDeltasForPivotNode[maxI];
	# initialize optimal attack vector for the best pivot node to target
	for i = 1:N
		if i in optimalTargetNodes
			ndeltas[i] = 0;
		else
			ndeltas[i] = 1;
		end
	end

	nnus = zeros(Float64, N);
	for i=1:N
	    nnus[i] = getValue(nus[i]);
	end

	################################################################
	# Slave problem 
	################################################################
	mm = getNonLinearModel();
	m = mm[1]; 
	deltas = mm[2];
	gammas = mm[3];
	t = mm[4];
	obj = mm[5];
	nus = mm[6];
	P = mm[7];
	Q = mm[8];
	pc = mm[9];
	qc = mm[10];
	pg = mm[11];
	qg = mm[12];
	
	# if slave problem, then maximize the rewards for attacker
	@setObjective(m, :Min, obj)		
			
	# pivot node voltage constraints
	addConstraint(m, t >= 0);
	for i = 1:N
		addConstraint(m, t >= nusL - nus[pivotNode]);
	end	
	
	for i = 1:N	
		addConstraint(m, deltas[i] == ndeltas[i]);
	end

	solve(m)

	ngammas = zeros(Float64, N);
	for i=1:N
	    ngammas[i] = getValue(gammas[i]);
	end

	nnus = zeros(Float64, N);
	for i=1:N
	    nnus[i] = getValue(nus[i]);
	end

	finalObjValue = getObjectiveValue(m);
	if finalObjValue > currentBestObjValue
		# update values
		currentBestObjValue = finalObjValue;
		j = 1;
		for i=1:N
		    if ndeltas[i] == 0
		    	targetNodes[j] = i;
		    	j += 1;
		    end
		end
	end
end
# Out:
#  a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557205668e+05, best bound -5.613557205668e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217809e+05, best bound -5.641148217809e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217809e+05, best bound -5.641148217809e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217809e+05, best bound -5.641148217809e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217809e+05, best bound -5.641148217809e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -561356
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557205668e+05, best bound -5.613557205668e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557205668e+05, best bound -5.613557205668e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -558597
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.585966193526e+05, best bound -5.585966193526e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -564115
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217809e+05, best bound -5.641148217809e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217809e+05, best bound -5.641148217809e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217809e+05, best bound -5.641148217809e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081014998e+05, best bound -5.663081014998e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081014998e+05, best bound -5.663081014998e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081014998e+05, best bound -5.663081014998e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -566308
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081014998e+05, best bound -5.663081014998e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -563549
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.635490002856e+05, best bound -5.635490002856e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.635490002856e+05, best bound -5.635490002856e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.635490002856e+05, best bound -5.635490002856e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217721e+05, best bound -5.641148217721e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217721e+05, best bound -5.641148217721e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217721e+05, best bound -5.641148217721e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217721e+05, best bound -5.641148217721e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -561356
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557205580e+05, best bound -5.613557205580e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -558597
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.585966193439e+05, best bound -5.585966193439e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557205580e+05, best bound -5.613557205580e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217651e+05, best bound -5.641148217651e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217651e+05, best bound -5.641148217651e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -564115
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217651e+05, best bound -5.641148217651e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148217651e+05, best bound -5.641148217651e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557205510e+05, best bound -5.613557205510e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557205510e+05, best bound -5.613557205510e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.585966193369e+05, best bound -5.585966193369e+05, gap 0.0%
# Optimize a model with 64 rows, 71 columns and 180 nonzeros
# Model has 7 quadratic constraints
# Presolve removed 42 rows and 35 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 64 columns, 160 nonzeros
# Variable types: 64 continuous, 0 integer (0 binary)
# Optimize a model with 50 rows, 64 columns and 160 nonzeros
# Model has 7 quadratic constraints
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 41 rows, 55 columns, 146 nonzeros
# Presolved model has 7 second-order cone constraints
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.690e+02
#  Factor NZ  : 4.070e+02
#  Factor Ops : 4.789e+03 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.19332883e+06 -4.38270709e+06  1.27e+00 7.53e+06  4.29e+06     0s
#    1   2.88052111e+06 -1.10014447e+07  1.34e-01 1.81e+06  8.57e+05     0s
#    2   1.86576953e+04 -2.26545770e+06  4.04e-03 1.92e+05  8.96e+04     0s
#    3   3.64386400e+03 -1.38612648e+05  4.04e-09 5.46e+03  3.68e+03     0s
#    4  -5.54236110e+03 -1.50721773e+04  2.22e-12 3.52e+02  2.43e+02     0s
#    5  -6.70374339e+03 -7.56204973e+03  6.99e-15 1.75e+01  1.82e+01     0s
#    6  -6.99946695e+03 -7.00118800e+03  1.22e-14 3.11e-02  3.54e-02     0s
#    7  -6.99996198e+03 -7.00002060e+03  9.65e-15 4.62e-04  1.02e-03     0s
#    8  -6.99999976e+03 -7.00000059e+03  6.66e-15 4.46e-07  1.31e-05     0s
#
# Barrier solved model in 8 iterations and 0.00 seconds
# Optimal objective -6.99999976e+03
#
#
# Root relaxation: objective -7.000000e+03, 0 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    -6999.999762 -6999.9998  0.00%     -    0s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 8 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -6.999999761521e+03, best bound -6.999999761521e+03, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -572888
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406911e+05, best bound -5.728879406911e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406911e+05, best bound -5.728879406911e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406911e+05, best bound -5.728879406911e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406911e+05, best bound -5.728879406911e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -572888
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406911e+05, best bound -5.728879406911e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406911e+05, best bound -5.728879406911e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406911e+05, best bound -5.728879406911e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -566308
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081015084e+05, best bound -5.663Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -572888
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406182e+05, best bound -5.728879406182e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406182e+05, best bound -5.728879406182e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406182e+05, best bound -5.728879406182e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406182e+05, best bound -5.728879406182e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -572888
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406182e+05, best bound -5.728879406182e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406182e+05, best bound -5.728879406182e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.728879406182e+05, best bound -5.728879406182e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081014035e+05, best bound -5.663081014035e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.635490001893e+05, best bound -5.635490001893e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -563549
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.635490001893e+05, best bound -5.635490001893e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.635490001893e+05, best bound -5.635490001893e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -566308
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081014035e+05, best bound -5.663081014035e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081014035e+05, best bound -5.663081014035e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081014035e+05, best bound -5.663081014035e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557204511e+05, best bound -5.613557204511e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.585966192369e+05, best bound -5.585966192369e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557204511e+05, best bound -5.613557204511e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -564115
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -564115
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -561356
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557204511e+05, best bound -5.613557204511e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557204511e+05, best bound -5.613557204511e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -558597
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.05s
#
# Explored 0 nodes (0 simplex iterations) in 0.05 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.585966192369e+05, best bound -5.585966192369e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -564115
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.04s
#
# Explored 0 nodes (0 simplex iterations) in 0.07 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081014035e+05, best bound -5.663081014035e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081014035e+05, best bound -5.663081014035e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081014035e+05, best bound -5.663081014035e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.663081014035e+05, best bound -5.663081014035e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -563549
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.635490001893e+05, best bound -5.635490001893e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.635490001893e+05, best bound -5.635490001893e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.635490001893e+05, best bound -5.635490001893e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -564115
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.02s
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -561356
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557204511e+05, best bound -5.613557204511e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.585966192369e+05, best bound -5.585966192369e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557204511e+05, best bound -5.613557204511e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -564115
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.641148216652e+05, best bound -5.641148216652e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Found heuristic solution: objective -561356
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557204511e+05, best bound -5.613557204511e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.613557204511e+05, best bound -5.613557204511e+05, gap 0.0%
# Optimize a model with 64 rows, 64 columns and 153 nonzeros
# Presolve removed 64 rows and 64 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 1 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.585966192369e+05, best bound -5.585966192369e+05, gap 0.0%
# Optimize a model with 64 rows, 71 columns and 180 nonzeros
# Model has 7 quadratic constraints
# Presolve removed 42 rows and 35 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 64 columns, 160 nonzeros
# Variable types: 64 continuous, 0 integer (0 binary)
# Optimize a model with 50 rows, 64 columns and 160 nonzeros
# Model has 7 quadratic constraints
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 41 rows, 55 columns, 146 nonzeros
# Presolved model has 7 second-order cone constraints
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.690e+02
#  Factor NZ  : 4.070e+02
#  Factor Ops : 4.789e+03 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.19332883e+06 -4.38270709e+06  1.27e+00 7.53e+06  4.29e+06     0s
#    1   2.88052111e+06 -1.10014447e+07  1.34e-01 1.81e+06  8.57e+05     0s
#    2   1.86576953e+04 -2.26545770e+06  4.04e-03 1.92e+05  8.96e+04     0s
#    3   3.64386400e+03 -1.38612648e+05  4.04e-09 5.46e+03  3.68e+03     0s
#    4  -5.54236110e+03 -1.50721773e+04  2.22e-12 3.52e+02  2.43e+02     0s
#    5  -6.70374339e+03 -7.56204973e+03  6.99e-15 1.75e+01  1.82e+01     0s
#    6  -6.99946695e+03 -7.00118800e+03  1.22e-14 3.11e-02  3.54e-02     0s
#    7  -6.99996198e+03 -7.00002060e+03  9.65e-15 4.62e-04  1.02e-03     0s
#    8  -6.99999976e+03 -7.00000059e+03  6.66e-15 4.46e-07  1.31e-05     0s
#
# Barrier solved model in 8 iterations and 0.00 seconds
# Optimal objective -6.99999976e+03
#
#
# Root relaxation: objective -7.000000e+03, 0 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    -6999.999762 -6999.9998  0.00%     -    0s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 8 (of 8 available processors)
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -6.999999761521e+03, best bound -6.999999761521e+03, gap 0.0%

# %%
targetNodes
# Out:
# 1-element Array{Int64,1}:
#  7
